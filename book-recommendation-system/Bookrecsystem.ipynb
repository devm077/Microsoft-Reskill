# %%
import pandas as pd

# Load the dataset
books_df = pd.read_csv('/content/books.csv')

def search_books(keyword):
    """
    Search for books that match the keyword in the title, authors, or publisher.
    """
    keyword = keyword.lower()
    results = books_df[
        books_df['title'].str.lower().str.contains(keyword) |
        books_df['authors'].str.lower().str.contains(keyword) |
        books_df['publisher'].str.lower().str.contains(keyword)
    ]
    return results


def display_books(books):
    """
    Display the list of books.
    """
    if books.empty:
        print("No books found.")
    else:
        for index, book in books.iterrows():
            print(f"Title: {book['title']}")
            print(f"Author: {book['authors']}")
            print(f"Average Rating: {book['average_rating']}")
            print(f"ISBN: {book['isbn']}")
            print(f"ISBN13: {book['isbn13']}")
            print(f"Language: {book['language_code']}")
            # Check if 'num_pages' column exists before printing
            if 'num_pages' in book:
                print(f"Number of Pages: {book['num_pages']}")
            print(f"Ratings Count: {book['ratings_count']}")
            print(f"Text Reviews Count: {book['text_reviews_count']}")
            print(f"Publication Date: {book['publication_date']}")
            print(f"Publisher: {book['publisher']}")
            print('-' * 40)

def main():
    print("Welcome to the Book Recommendation Program!")
    keyword = input("Enter a keyword to search for books: ")
    results = search_books(keyword)
    display_books(results)

if __name__ == "__main__":
    main()
# Out:
# Welcome to the Book Recommendation Program!
# Enter a keyword to search for books: Bill Bryson
# Title: A Short History of Nearly Everything
# Author: Bill Bryson
# Average Rating: 4.21
# ISBN: 076790818X
# ISBN13: 9.78077E+12
# Language: eng
# Ratings Count: 248558
# Text Reviews Count: 9396
# Publication Date: 9/14/2004
# Publisher: Broadway Books
# ----------------------------------------
# Title: Bill Bryson's African Diary
# Author: Bill Bryson
# Average Rating: 3.44
# ISBN: 767915062
# ISBN13: 9.78077E+12
# Language: eng
# Ratings Count: 7270
# Text Reviews Count: 499
# Publication Date: 12-03-2002
# Publisher: Broadway Books
# ----------------------------------------
# Title: Bryson's Dictionary of Troublesome Words: A Writer's Guide to Getting It Right
# Author: Bill Bryson
# Average Rating: 3.87
# ISBN: 767910435
# ISBN13: 9.78077E+12
# Language: eng
# Ratings Count: 2088
# Text Reviews Count: 131
# Publication Date: 9/14/2004
# Publisher: Broadway Books
# ----------------------------------------
# Title: In a Sunburned Country
# Author: Bill Bryson
# Average Rating: 4.07
# ISBN: 767903862
# ISBN13: 9.78077E+12
# Language: eng
# Ratings Count: 72451
# Text Reviews Count: 4245
# Publication Date: 5/15/2001
# Publisher: Broadway Books
# ----------------------------------------
# Title: I'm a Stranger Here Myself: Notes on Returning to America After Twenty Years Away
# Author: Bill Bryson
# Average Rating: 3.9
# ISBN: 076790382X
# ISBN13: 9.78077E+12
# Language: eng
# Ratings Count: 49240
# Publication Date: 01-02-1999
# Publisher: Black Swan
# ----------------------------------------
# Title: Made in America: An Informal History of the English Language in the United States
# Author: Bill Bryson
# Average Rating: 3.91
# ISBN: 380713810
# ISBN13: 9.78038E+12
# Language: eng
# Ratings Count: 10836
# Text Reviews Count: 613
# Publication Date: 10/23/2001
# Publisher: Avon Books
# ----------------------------------------
# Title: Bill Bryson's African Diary
# Author: Bill Bryson
# Average Rating: 3.44
# ISBN: 385605145
# ISBN13: 9.78039E+12
# Language: eng
# Ratings Count: 264
# Text Reviews Count: 22
# Publication Date: 12-02-2002
# Publisher: Doubleday
# ----------------------------------------
# Title: Down Under
# Author: Bill Bryson
# Average Rating: 4.07
# ISBN: 055299703X
# ISBN13: 9.78055E+12
# Language: eng
# Ratings Count: 4510
# Text Reviews Count: 392
# Publication Date: 08-06-2001
# Publisher: Black Swan
# ----------------------------------------
# Title: A Walk in the Woods: Rediscovering America on the Appalachian Trail
# Author: Bill Bryson
# Average Rating: 4.06
# ISBN: 767902513
# ISBN13: 9.78077E+12
# Language: eng
# Ratings Count: 1405
# Text Reviews Count: 266
# Publication Date: 05-04-1998
# Publisher: Bantam Doubleday Dell Publishing Group
# ----------------------------------------
# Title: The Life and Times of the Thunderbolt Kid: A Memoir
# Author: Bill Bryson
# Average Rating: 3.94
# ISBN: 767919378
# ISBN13: 9.78077E+12
# Language: en-US
# Ratings Count: 1329
# Text Reviews Count: 250
# Publication Date: 9/25/2007
# Publisher: Broadway Books
# ----------------------------------------
# Title: Bill Bryson: The Complete Notes
# Author: Bill Bryson
# Average Rating: 4.09
# ISBN: 038560131X
# ISBN13: 9.78039E+12
# Language: eng
# Ratings Count: 901
# Text Reviews Count: 36
# Publication Date: 10-05-2000
# Publisher: Doubleday
# ----------------------------------------
# Title: Motel Blues
# Author: Bill Bryson/David B. Ellis
# Average Rating: 3.83
# ISBN: 2228897353
# ISBN13: 9.78223E+12
# Language: fre
# Ratings Count: 17
# Text Reviews Count: 3
# Publication Date: 4/15/2003
# Publisher: Payot
# ----------------------------------------
# Title: Journeys in English
# Author: Bill Bryson
# Average Rating: 3.72
# ISBN: 563496266
# ISBN13: 9.78056E+12
# Language: eng
# Ratings Count: 510
# Text Reviews Count: 60
# Publication Date: 02-02-2004
# Publisher: BBC Physical Audio
# ----------------------------------------
# Title: Una breve historia de casi todo
# Author: Bill Bryson/José Manuel Álvarez
# Average Rating: 4.21
# ISBN: 8478713808
# ISBN13: 9.78848E+12
# Language: spa
# Ratings Count: 713
# Text Reviews Count: 68
# Publication Date: 4/30/2006
# Publisher: Rba Libros
# ----------------------------------------
